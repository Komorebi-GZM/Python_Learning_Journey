# %%
# ==================== 本地 Python 3.14.2 环境测试 ====================
import sys
import platform

# 测试1：Python 版本
print("=== 测试1：Python 版本信息 ===")
print(f"Python 版本：{sys.version}")
print(f"Python 路径：{sys.executable}")
print(f"系统平台：{platform.platform()}")

# 测试2：基础语法（3.14 新特性验证）
print("\n=== 测试2：基础语法测试 ===")
# 3.10+ 匹配语法
match 5:
    case 1 | 2 | 3:
        print("1-3")
    case 4 | 5 | 6:
        print("4-6（匹配成功）")
    case _:
        print("其他")

# 测试3：文件操作
print("\n=== 测试3：文件读写测试 ===")
with open("test_local_temp.txt", "w", encoding="utf-8") as f:
    f.write("本地 Python 3.14.2 测试成功！")

with open("test_local_temp.txt", "r", encoding="utf-8") as f:
    content = f.read()
print(f"文件内容：{content}")

# 清理临时文件
import os
os.remove("test_local_temp.txt")

print("\n✅ 本地 Python 3.14.2 环境测试通过！")
# Out:
# === 测试1：Python 版本信息 ===
# Python 版本：3.14.2 (tags/v3.14.2:df79316, Dec  5 2025, 17:18:21) [MSC v.1944 64 bit (AMD64)]
# Python 路径：c:\Users\48769\AppData\Local\Programs\Python\Python314\python.exe
# 系统平台：Windows-11-10.0.26100-SP0
#
# === 测试2：基础语法测试 ===
# 4-6（匹配成功）
#
# === 测试3：文件读写测试 ===
# 文件内容：本地 Python 3.14.2 测试成功！
#
# ✅ 本地 Python 3.14.2 环境测试通过！
