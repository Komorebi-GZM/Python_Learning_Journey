# %%
# 测试1：自动导入pandas/numpy
data = pd.DataFrame({
    '姓名': ['张三', '李四', '王五'],
    '年龄': [25, 30, 35],
    '薪资': [8000, 12000, 15000]
})
print("=== 测试pandas数据框 ===")
print(data)

# 测试2：自动导入matplotlib+中文显示
plt.figure(figsize=(8, 5))
sns.barplot(x='姓名', y='薪资', data=data)
plt.title("员工薪资对比（中文标题测试）")
plt.xlabel("姓名")
plt.ylabel("月薪（元）")
plt.grid(axis='y', alpha=0.3)
plt.show()

# 测试3：numpy计算
print("\n=== 测试numpy计算 ===")
arr = np.array([1, 2, 3, 4, 5])
print(f"数组平方：{arr ** 2}")
print(f"数组均值：{np.mean(arr)}")
